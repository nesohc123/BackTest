# %%
from BackTest.Demos import get_MACD_signal, get_reversal_signal
from BackTest.BackTest import Single_BackTest, Multiple_BackTest
import pandas as pd

demo_signal_1 = get_reversal_signal()
demo_signal_2 = get_MACD_signal()

demo_multi_signal = pd.merge(demo_signal_1, demo_signal_2, 'left', ['date', 'stk_id'])

demo_stock_pool = list(set(demo_signal_1['stk_id']))[:10]

model_1 = Single_BackTest()
model_2 = Single_BackTest()
model_3 = Single_BackTest()
model_4 = Single_BackTest()

model_5 = Multiple_BackTest()
model_6 = Multiple_BackTest()
model_7 = Multiple_BackTest()

model_8 = Single_BackTest()
# Out:
# Initializing BACKTEST Package
# e:\Python env\venv\.venv\BackTest\BackTest\Demos.py:23: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead.
#   basic_data['selected'] = basic_data['selected_1'] * basic_data['selected_2'] * basic_data['selected_3']
# e:\Python env\venv\.venv\BackTest\BackTest\Demos.py:48: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead.
#   basic_data['selected'] = basic_data['selected_1'] * basic_data['selected_2'] * basic_data['selected_3']

# %%
model_1.fit(demo_signal_1)
model_1.show()
# Out:
# ['cum_pnl', 'benchmark']
# the annual return is: 0.10727201070490827
# the excess annual return is :0.11757353642392629
# the Sharpe ratio is: 1.861412035655745
# the excess Sharpe ratio is: 2.1222197593656107
# the maximum drawdown is: 0.020582059607743227
# the excess return max-drawdown is: 0.019595062014978043
# the R-squared of this signal is: 0.00011264240622401966
# the excess_Rsquard of this signal is: 0.00015042750126519755
# 0

# %%
model_2.fit(demo_signal_1, groups = 10)
model_2.LnS_PnL_show()
# Out:
# group_1 is the largest short and group_10 is the largest long
# the R-squared of the group_1 is: 0.0001587751805190402
# the R-squared of the group_2 is: 2.1459673856524995e-05
# the R-squared of the group_3 is: -1.1176196662824214e-05
# the R-squared of the group_4 is: -6.303319625925245e-05
# the R-squared of the group_5 is: -8.816534712954702e-05
# the R-squared of the group_6 is: 0.00021622280368550052
# the R-squared of the group_7 is: 0.0004411760566558769
# the R-squared of the group_8 is: 0.000641256704696031
# the R-squared of the group_9 is: 0.0007964893376398483
# the R-squared of the group_10 is: 0.0004812514546114889
# the annual return is: 0.10727201070490827
# the excess annual return is :0.11757353642392629
# the Sharpe ratio is: 1.861412035655745
# the excess Sharpe ratio is: 2.1222197593656107
# the maximum drawdown is: 0.020582059607743227
# the excess return max-drawdown is: 0.019595062014978043
# the R-squared of this signal is: 0.00011264240622401966
# the excess_Rsquard of this signal is: 0.00015042750126519755
# 0

# %%
model_3.fit(demo_signal_1, stock_list = demo_stock_pool)
model_3.show()
# Out:
# ['cum_pnl', 'benchmark']
# the annual return is: 0.23947939273846133
# the excess annual return is :0.20049201299844066
# the Sharpe ratio is: 0.47786527319821637
# the excess Sharpe ratio is: 0.8139654668171957
# the maximum drawdown is: 0.27862753035164706
# the excess return max-drawdown is: 0.21162925333446533
# the R-squared of this signal is: 3.007897837799322e-06
# the excess_Rsquard of this signal is: 7.76446716049702e-06
# 0

# %%
model_4.fit(demo_signal_1, stock_list = demo_stock_pool, groups = 10)
model_4.LnS_PnL_show()
# Out:
# group_1 is the largest short and group_10 is the largest long
# the R-squared of the group_1 is: -0.0018682352684086946
# the R-squared of the group_2 is: -0.0008010811432806028
# the R-squared of the group_3 is: -1.5985230461760583e-05
# the R-squared of the group_4 is: -8.768385664929159e-05
# the R-squared of the group_5 is: -0.0002742036521455825
# the R-squared of the group_6 is: 0.00021622280368550052
# the R-squared of the group_7 is: 0.0004411760566558769
# the R-squared of the group_8 is: 0.000641256704696031
# the R-squared of the group_9 is: 0.0007964893376398483
# the R-squared of the group_10 is: 0.0004812514546114889
# the annual return is: 0.23947939273846133
# the excess annual return is :0.20049201299844066
# the Sharpe ratio is: 0.47786527319821637
# the excess Sharpe ratio is: 0.8139654668171957
# the maximum drawdown is: 0.27862753035164706
# the excess return max-drawdown is: 0.21162925333446533
# the R-squared of this signal is: 3.007897837799322e-06
# the excess_Rsquard of this signal is: 7.76446716049702e-06
# 0

# %%
model_5.multiple_signals_fit(demo_multi_signal)
model_5.show()
model_5.show_corr()
# Out:
# ['cum_pnl', 'benchmark']
# the annual return is: 0.14650064831422585
# the excess annual return is :0.14715262983557462
# the Sharpe ratio is: 0.5302833395864257
# the excess Sharpe ratio is: 0.5339043176611586
# the maximum drawdown is: 0.010304974142028685
# the excess return max-drawdown is: 0.010201643950917312
# the R-squared of this signal is: 0.0002407321917323958
# the excess_Rsquard of this signal is: 0.0002785288807055001
# 0

# %%
model_6.multiple_signals_fit(demo_multi_signal, groups = 10)
model_6.LnS_PnL_show()
# Out:
# group_1 is the largest short and group_10 is the largest long
# the R-squared of the group_1 is: 0.0004753899205747119
# the R-squared of the group_2 is: 6.614959326039856e-08
# the R-squared of the group_3 is: -4.568750916273504e-05
# the R-squared of the group_4 is: -0.00017020464495141253
# the R-squared of the group_5 is: -0.0003816654680522919
# the R-squared of the group_6 is: 0.0005409017143630256
# the R-squared of the group_7 is: 0.001054305477823528
# the R-squared of the group_8 is: 0.0010547988771969967
# the R-squared of the group_9 is: 0.0011270957629283644
# the R-squared of the group_10 is: 0.0011264208445283445
# the annual return is: 0.14650064831422585
# the excess annual return is :0.14715262983557462
# the Sharpe ratio is: 0.5302833395864257
# the excess Sharpe ratio is: 0.5339043176611586
# the maximum drawdown is: 0.010304974142028685
# the excess return max-drawdown is: 0.010201643950917312
# the R-squared of this signal is: 0.0002407321917323958
# the excess_Rsquard of this signal is: 0.0002785288807055001
# 0

# %%
model_7.multiple_signals_fit(demo_multi_signal, stock_list = demo_stock_pool)
model_7.show()
# Out:
# ['cum_pnl', 'benchmark']
# the annual return is: 0.2923696500906219
# the excess annual return is :0.30285453866371004
# the Sharpe ratio is: 0.1307960847779329
# the excess Sharpe ratio is: 0.2591357477105717
# the maximum drawdown is: 0.1548088776305549
# the excess return max-drawdown is: 0.05234487537632302
# the R-squared of this signal is: 6.888160855392492e-05
# the excess_Rsquard of this signal is: 4.9241643498405744e-05
# 0

# %%
start_time = pd.Timestamp('2022-01-01')
end_time = pd.Timestamp('2022-06-30')
demo_signal_3 = get_reversal_signal(10, start_time=start_time, end_time = end_time)

model_8.fit(demo_signal_3)
model_8.show()
# Out:
# e:\Python env\venv\.venv\BackTest\BackTest\Demos.py:23: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead.
#   basic_data['selected'] = basic_data['selected_1'] * basic_data['selected_2'] * basic_data['selected_3']
# ['cum_pnl', 'benchmark']
# the annual return is: 0.10061969447365293
# the excess annual return is :0.1020228315857186
# the Sharpe ratio is: 0.4516286209417199
# the excess Sharpe ratio is: 0.4629552543706022
# the maximum drawdown is: 0.00510372678514612
# the excess return max-drawdown is: 0.005062546539377944
# the R-squared of this signal is: 0.00010137388818034408
# the excess_Rsquard of this signal is: 0.00012909623854699052
# 0
